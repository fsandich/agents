# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# True

# %%
# Comprobamos las claves

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI existe y empieza por sk-proj-

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

openai = OpenAI()

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT 4.1 nano, el modelo increíblemente económico.

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 es igual a 4.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Si cinco máquinas pueden fabricar cinco artículos en cinco minutos, ¿cuánto tiempo tardarán cien máquinas en fabricar cien artículos?

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Vamos a analizar el problema paso a paso.
#
# **Datos del problema:**
# - 5 máquinas fabrican 5 artículos en 5 minutos.
#
# Queremos saber: **¿Cuánto tiempo tardarán 100 máquinas en fabricar 100 artículos?**
#
# ---
#
# ### Paso 1: Encontrar la tasa de trabajo por máquina
#
# Si 5 máquinas fabrican 5 artículos en 5 minutos, entonces:
#
# - En 5 minutos: 5 máquinas → 5 artículos
# - Por máquina: 1 máquina en 5 minutos → 1 artículo
#
# Esto indica que **cada máquina fabrica 1 artículo en 5 minutos**.
#
# ---
#
# ### Paso 2: Calcular el tiempo para 100 máquinas fabricando 100 artículos
#
# Dado que cada máquina produce 1 artículo en 5 minutos:
#
# - 100 máquinas trabajando al mismo tiempo fabricarán 100 artículos en **5 minutos**.
#
# ---
#
# ### **Respuesta:**
#
# Las 100 máquinas tardarán **5 minutos** en fabricar 100 artículos.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Vamos a analizar el problema paso a paso.
#
# **Datos del problema:**
# - 5 máquinas fabrican 5 artículos en 5 minutos.
#
# Queremos saber: **¿Cuánto tiempo tardarán 100 máquinas en fabricar 100 artículos?**
#
# ---
#
# ### Paso 1: Encontrar la tasa de trabajo por máquina
#
# Si 5 máquinas fabrican 5 artículos en 5 minutos, entonces:
#
# - En 5 minutos: 5 máquinas → 5 artículos
# - Por máquina: 1 máquina en 5 minutos → 1 artículo
#
# Esto indica que **cada máquina fabrica 1 artículo en 5 minutos**.
#
# ---
#
# ### Paso 2: Calcular el tiempo para 100 máquinas fabricando 100 artículos
#
# Dado que cada máquina produce 1 artículo en 5 minutos:
#
# - 100 máquinas trabajando al mismo tiempo fabricarán 100 artículos en **5 minutos**.
#
# ---
#
# ### **Respuesta:**
#
# Las 100 máquinas tardarán **5 minutos** en fabricar 100 artículos.

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# Priemro creamos el mensaje


messages = [{"role": "user", "content": "Menciona 1 area de negocio que valga la pena explorar para una oportunidad de IA con Agentic."}]

# Hacemos la primera llamada:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Luego leemos la idea de negocio:

business_idea = response.choices[0].message.content
print(business_idea)

# Ahora le pedimos al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.

messages = [{"role": "user", "content": f"Presenta un problema en la industria de {business_idea} que pueda ser propicio para una solución con Agentic."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

problema_area_negocio = response.choices[0].message.content
print(problema_area_negocio)    

# Ahora le pedimos al LLM que proponga la solución de IA con Agentic.

messages = [{"role": "user", "content": f"Propón una solución de IA con Agentic para el problema de {problema_area_negocio}."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solucion_ia_agentic = response.choices[0].message.content
print(solucion_ia_agentic)

# Y repetimos!
# Out:
# Una área de negocio que vale la pena explorar para una oportunidad de IA con Agentic es **el sector de servicios financieros, particularmente en la gestión automatizada de inversiones y asesoría financiera personalizada**.
#
# Agentic puede potenciar plataformas que utilicen agentes inteligentes para analizar grandes volúmenes de datos del mercado en tiempo real, evaluar perfiles de riesgo de los clientes, y ofrecer recomendaciones de inversión precisas y adaptativas, todo de manera autónoma o semiautónoma. Esto no solo mejora la eficiencia y reduce costos, sino que también democratiza el acceso a asesoría financiera avanzada.
# Un problema relevante en la industria de servicios financieros, específicamente en la gestión automatizada de inversiones y asesoría financiera personalizada, es la **falta de adaptabilidad y personalización eficaz en las recomendaciones de inversión frente a condiciones de mercado volátiles y perfiles de clientes dinámicos**.
#
# Actualmente, muchas plataformas automatizadas ofrecen recomendaciones basadas en modelos estadísticos tradicionales o reglas fijas que no se ajustan rápidamente a cambios repentinos en el mercado ni capturan a fondo las variaciones en el perfil y preferencias del cliente (como cambios en su situación financiera, metas, o tolerancia al riesgo). Esto puede llevar a decisiones subóptimas, pérdida de confianza del usuario y menor adopción de servicios automáticos.
#
# Aquí es donde una solución con Agentic puede ser especialmente propicia: al integrar agentes inteligentes que monitoricen en tiempo real tanto el entorno financiero como las condiciones individuales de cada cliente, puede:
#
# - Analizar grandes volúmenes de datos del mercado y señales emergentes para detectar movimientos relevantes que impacten en las carteras.
# - Evaluar continuamente el perfil de riesgo y objetivos personales del cliente mediante interacciones dinámicas y aprendizaje adaptativo.
# - Ajustar recomendaciones de inversión de forma proactiva, justa y personalizada, actuando de manera autónoma o semiautónoma para optimizar resultados y mitigar riesgos.
# - Facilitar explicaciones transparentes y apoyo interactivo al cliente para fomentar confianza y educación financiera.
#
# Así, una solución Agentic puede superar las limitaciones actuales, aumentando la eficacia, eficiencia y alcance de la asesoría financiera automatizada en un contexto complejo y cambiante.
# Claro, a continuación propongo una solución de IA con enfoque Agentic para abordar la falta de adaptabilidad y personalización eficaz en la gestión automatizada de inversiones y asesoría financiera personalizada:
#
# ---
#
# ### Solución IA Agentic para Gestión Adaptativa y Personalizada de Inversiones
#
# **Objetivo:**
# Desarrollar un sistema de agentes inteligentes (Agentic AI) capaz de operar de manera autónoma y coordinada para monitorizar, analizar y ajustar dinámicamente las recomendaciones de inversión, incorporando tanto datos de mercado en tiempo real como la evolución continua del perfil y objetivos del cliente.
#
# ---
#
# ### Arquitectura y Funcionalidades Clave
#
# 1. **Agente de Monitoreo del Mercado (Market Watcher Agent)**
#    - Recopila y procesa datos financieros en tiempo real: precios, volúmenes, indicadores técnicos, noticias, eventos económicos y señales emergentes (sentimiento de mercado, tweets, etc.).
#    - Utiliza modelos avanzados de análisis predictivo (machine learning, NLP, deep learning) para detectar cambios repentinos o tendencias relevantes.
#
# 2. **Agente Perfilador de Cliente (Client Profiler Agent)**
#    - Mantiene un perfil dinámico del cliente que incluye situación financiera actual, objetivos de inversión, nivel de tolerancia al riesgo y preferencias personales.
#    - Interactúa periódicamente con el cliente vía chatbots conversacionales o interfaces intuitivas para captar cambios en circunstancias o prioridades (ej. nuevo empleo, necesidad de liquidez, mayor aversión al riesgo).
#    - Utiliza aprendizaje adaptativo para actualizar el perfil basado en comportamiento observado (patrones de inversión, interacción con recomendaciones previas).
#
# 3. **Agente de Optimización de Portafolio (Portfolio Optimizer Agent)**
#    - Integra la información del agente de mercado y del agente perfilador para diseñar recomendaciones de inversión personalizadas.
#    - Usa técnicas de optimización multiobjetivo que ponderan riesgo, retorno esperado, liquidez y objetivos personales, ajustándose en tiempo real a las condiciones cambiantes.
#    - Puede ejecutar o recomendar ajustes de portafolio automáticamente (autonomía configurada), con capacidad de detenerse y solicitar aprobación humana si se presentan escenarios de alto impacto o incertidumbre.
#
# 4. **Agente Explicador y Educativo (Explainer Agent)**
#    - Genera explicaciones claras y comprensibles sobre las recomendaciones y cambios realizados, adaptándose al nivel de conocimiento financiero del cliente.
#    - Facilita apoyo educativo interactivo para que el cliente comprenda mejor las decisiones, fomentando confianza y empoderándolo en la gestión de sus inversiones.
#    - Permite el feedback del usuario para mejorar el sistema y ajustar el nivel de personalización.
#
# ---
#
# ### Ventajas de la Solución Agentic
#
# - **Adaptabilidad continua:** Monitorización activa y autoajuste frente a mercados volátiles y cambios en cliente.
# - **Personalización profunda:** Modelado dinámico de cliente que evoluciona con la vida real y preferencias, no sólo cuestionarios iniciales estáticos.
# - **Autonomía controlada:** Equilibrio entre autonomía y supervisión humana para escenarios complejos o sensibles.
# - **Transparencia y confianza:** Explicaciones efectivas y diálogo bidireccional incrementan la adopción y satisfacción.
# - **Escalabilidad:** Capacidad para atender grandes volúmenes de clientes y datos en paralelo mediante agentes distribuidos y coordinados.
#
# ---
#
# ### Implementación Técnica (Resumen)
#
# - **Plataforma cloud**, con orquestación de microservicios agentic (podría usar frameworks de multi-agent systems como JADE, o arquitecturas basadas en Kubernetes).
# - **Integración de APIs financieras y bases de datos en tiempo real.**
# - **Módulos de ML/DL para análisis de series temporales, NLP, clustering y personalización.**
# - **Interfaces chatbot, paneles web/móvil para interacción cliente-agent.**
# - **Mecanismos de seguridad, privacidad y cumplimiento normativo financiero.**
#
# ---
#
# Esta solución representa un sistema inteligente, proactivo y centrado en el cliente para superar las actuales limitaciones en asesoría financiera automatizada mediante el poder de agentes autónomos coordinados (Agentic AI). ¿Quieres que te ayude a detallar algún componente o enfocarlo en un caso específico?

# %%
from IPython.display import Markdown, display

display(Markdown(solucion_ia_agentic))
# Out:
# Claro, a continuación propongo una solución de IA con enfoque Agentic para abordar la falta de adaptabilidad y personalización eficaz en la gestión automatizada de inversiones y asesoría financiera personalizada:
#
# ---
#
# ### Solución IA Agentic para Gestión Adaptativa y Personalizada de Inversiones
#
# **Objetivo:**
# Desarrollar un sistema de agentes inteligentes (Agentic AI) capaz de operar de manera autónoma y coordinada para monitorizar, analizar y ajustar dinámicamente las recomendaciones de inversión, incorporando tanto datos de mercado en tiempo real como la evolución continua del perfil y objetivos del cliente.
#
# ---
#
# ### Arquitectura y Funcionalidades Clave
#
# 1. **Agente de Monitoreo del Mercado (Market Watcher Agent)**
#    - Recopila y procesa datos financieros en tiempo real: precios, volúmenes, indicadores técnicos, noticias, eventos económicos y señales emergentes (sentimiento de mercado, tweets, etc.).
#    - Utiliza modelos avanzados de análisis predictivo (machine learning, NLP, deep learning) para detectar cambios repentinos o tendencias relevantes.
#
# 2. **Agente Perfilador de Cliente (Client Profiler Agent)**
#    - Mantiene un perfil dinámico del cliente que incluye situación financiera actual, objetivos de inversión, nivel de tolerancia al riesgo y preferencias personales.
#    - Interactúa periódicamente con el cliente vía chatbots conversacionales o interfaces intuitivas para captar cambios en circunstancias o prioridades (ej. nuevo empleo, necesidad de liquidez, mayor aversión al riesgo).
#    - Utiliza aprendizaje adaptativo para actualizar el perfil basado en comportamiento observado (patrones de inversión, interacción con recomendaciones previas).
#
# 3. **Agente de Optimización de Portafolio (Portfolio Optimizer Agent)**
#    - Integra la información del agente de mercado y del agente perfilador para diseñar recomendaciones de inversión personalizadas.
#    - Usa técnicas de optimización multiobjetivo que ponderan riesgo, retorno esperado, liquidez y objetivos personales, ajustándose en tiempo real a las condiciones cambiantes.
#    - Puede ejecutar o recomendar ajustes de portafolio automáticamente (autonomía configurada), con capacidad de detenerse y solicitar aprobación humana si se presentan escenarios de alto impacto o incertidumbre.
#
# 4. **Agente Explicador y Educativo (Explainer Agent)**
#    - Genera explicaciones claras y comprensibles sobre las recomendaciones y cambios realizados, adaptándose al nivel de conocimiento financiero del cliente.
#    - Facilita apoyo educativo interactivo para que el cliente comprenda mejor las decisiones, fomentando confianza y empoderándolo en la gestión de sus inversiones.
#    - Permite el feedback del usuario para mejorar el sistema y ajustar el nivel de personalización.
#
# ---
#
# ### Ventajas de la Solución Agentic
#
# - **Adaptabilidad continua:** Monitorización activa y autoajuste frente a mercados volátiles y cambios en cliente.
# - **Personalización profunda:** Modelado dinámico de cliente que evoluciona con la vida real y preferencias, no sólo cuestionarios iniciales estáticos.
# - **Autonomía controlada:** Equilibrio entre autonomía y supervisión humana para escenarios complejos o sensibles.
# - **Transparencia y confianza:** Explicaciones efectivas y diálogo bidireccional incrementan la adopción y satisfacción.
# - **Escalabilidad:** Capacidad para atender grandes volúmenes de clientes y datos en paralelo mediante agentes distribuidos y coordinados.
#
# ---
#
# ### Implementación Técnica (Resumen)
#
# - **Plataforma cloud**, con orquestación de microservicios agentic (podría usar frameworks de multi-agent systems como JADE, o arquitecturas basadas en Kubernetes).
# - **Integración de APIs financieras y bases de datos en tiempo real.**
# - **Módulos de ML/DL para análisis de series temporales, NLP, clustering y personalización.**
# - **Interfaces chatbot, paneles web/móvil para interacción cliente-agent.**
# - **Mecanismos de seguridad, privacidad y cumplimiento normativo financiero.**
#
# ---
#
# Esta solución representa un sistema inteligente, proactivo y centrado en el cliente para superar las actuales limitaciones en asesoría financiera automatizada mediante el poder de agentes autónomos coordinados (Agentic AI). ¿Quieres que te ayude a detallar algún componente o enfocarlo en un caso específico?
